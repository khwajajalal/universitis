# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r'C:\Users\Jalal\Desktop\Programing\Python\Data\universities.csv')
df.head(10)
# Out:
#                                                 name  \
# 0            A T Still University of Health Sciences
# 1                       Abilene Christian University
# 2               Abraham Baldwin Agricultural College
# 3                                    Academy College
# 4               Academy for Five Element Acupuncture
# 5                          Academy of Art University
# 6     Academy of Chinese Culture and Health Sciences
# 7                       Academy of Oriental Medicine
# 8                              Academy of Vocal Arts
# 9  Acupuncture and Integrative Medicine College-B...
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# 3  1101 E. 78th Street, Suite 100, Minneapolis, M...  www.academycollege.edu
# 4         305 SE 2nd Ave, Gainesville, Florida 32601   www.acupuncturist.edu
# 5  79 New Montgomery, San Francisco, California 9...      www.academyart.edu
# 6            1601 Clay St, Oakland, California 94612           www.acchs.edu
# 7    2700 W Anderson Ln Ste 204, Austin, Texas 78757            www.aoma.edu
# 8  1920 Spruce St, Philadelphia, Pennsylvania 191...        www.avaopera.org
# 9      2550 Shattuck Ave, Berkeley, California 94704            www.aimc.edu
#
#                                                 Type     Size
# 0                     4-year, Private not-for-profit   3480.0
# 1                     4-year, Private not-for-profit   4669.0
# 2              4-year, primarily associate's, Public   3600.0
# 3  4-year, primarily associate's, Private for-profit    165.0
# 4                     4-year, Private not-for-profit     51.0
# 5                         4-year, Private for-profit  13181.0
# 6                     4-year, Private not-for-profit     92.0
# 7                         4-year, Private for-profit    207.0
# 8                     4-year, Private not-for-profit     27.0
# 9                     4-year, Private not-for-profit    181.0

# %% [markdown]
#  Assignment: The university dataset (You may work solo or with one other person. Each person should have their own github repo with the completed assignment when you are done.)
# Load the university dataset (link below) into a pandas dataframe.
# Using pandas, find both the mean and median size by each university type (as given in the dataframe), ordered by average size in ascending order.
# Make new columns  in the dataframe from existing data for the following attributes:
# City
# State
# ZipCode
# Private or Public
# for-profit or not-for-profit
# primarily associate's (1 for Yes, 0 for No)
#  Using the new columns you've made above (and excluding the original type column), find both the mean and median size of each university by State, by Private or Public, and by whether the university is primarily associate's or not.
# Use the tools you've learned to compute at **least** one other aggregate from the dataset
# Save the updated dataframe as a csv  (using the pandas to_csv method) and commit your files, and push up to github.

# %% [markdown]
# Using pandas, find both the mean and median size by each university type (as given in the dataframe), ordered by average size in ascending order.

# %%
# df.columns

# %%
df.groupby('Type')['Size'].agg({'mean', 'median'}).sort_values('mean')
# Out:
#                                                             mean  median
# Type
# 4-year, primarily associate's, Private for-profit     934.380597   564.5
# 4-year, primarily associate's, Private not-for-...   1129.413793   768.0
# 4-year, Private not-for-profit                       2399.885696  1206.0
# 4-year, Private for-profit                           3504.501859   730.0
# 4-year, primarily associate's, Public                6889.366197  3558.0
# 4-year, Public                                      11478.913765  7669.0

# %%
df.columns
# Out:
# Index(['name', 'address', 'Website', 'Type', 'Size'], dtype='object')

# %%
address=df['address']
# address.hea()
df[['street_address', 'city', 'state']]=df['address'].str.rsplit(',', 2, expand=True)
df[['state_','Zip']]=df['state'].str.rsplit(' ',1,expand=True)
df.drop('state',axis='columns',inplace=True)
df.head()
# Out:
#                                       name  \
# 0  A T Still University of Health Sciences
# 1             Abilene Christian University
# 2     Abraham Baldwin Agricultural College
# 3                          Academy College
# 4     Academy for Five Element Acupuncture
#
#                                              address                 Website  \
# 0        800 W Jefferson, Kirksville, Missouri 63501            WWW.ATSU.EDU
# 1            1600 Campus Court, Abilene, Texas 79699             www.acu.edu
# 2         2802 Moore Hwy, Tifton, Georgia 31793-2601            www.abac.edu
# 3  1101 E. 78th Street, Suite 100, Minneapolis, M...  www.academycollege.edu
# 4         305 SE 2nd Ave, Gainesville, Florida 32601   www.acupuncturist.edu
#
#                                                 Type    Size  \
# 0                     4-year, Private not-for-profit  3480.0
# 1                     4-year, Private not-for-profit  4669.0
# 2              4-year, primarily associate's, Public  3600.0
# 3  4-year, primarily associate's, Private for-profit   165.0
# 4                     4-year, Private not-for-profit    51.0
#
#                    street_address          city      state_         Zip
# 0                 800 W Jefferson    Kirksville    Missouri       63501
# 1               1600 Campus Court       Abilene       Texas       79699
# 2                  2802 Moore Hwy        Tifton     Georgia  31793-2601
# 3  1101 E. 78th Street, Suite 100   Minneapolis   Minnesota  55420-1554
# 4                  305 SE 2nd Ave   Gainesville     Florida       32601

# %%
# df.state_.value_counts()

# %%
df.address.head()
# Out:
# 0          800 W Jefferson, Kirksville, Missouri 63501
# 1              1600 Campus Court, Abilene, Texas 79699
# 2           2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3    1101 E. 78th Street, Suite 100, Minneapolis, M...
# 4           305 SE 2nd Ave, Gainesville, Florida 32601
# Name: address, dtype: object

# %%
# df['address']=df.address.str.strip()
# # df1=df.address.str.split(',', expand=True)
# # df.address.head()
# address=df['address']
# # # address[address.str.count(',')>2]
# # address.loc[address.str.count(',')>2].str.replace(',','',n=1)

# # # # # address[address.str.count(',')>2].count()
# # # address[address.str.count(',')>2]
# # address.loc[address.str.count(',')>2]
# # address=[str.replace(',','',n=1) for x in address if address[x.str.count(',')>2]]
# address1=address.str.rsplit(' ',expand=True,n=3)
# # address1[3].unique()
# # columns=['city', 'state', 'Zip Code']
# # address1.columns=columns
# address1

# %%
df.Type.unique()
df['fp_nfp']=np.where(df['Type'].str.contains(' for'), 'for-profit', 'not-for-profit')
df['primarily_associate']=np.where(df['Type'].str.contains('primar'), 1,0)
df['public?']=np.where(df['Type'].str.contains('Private'), 'Private', 'Public')

# %%
df
# Out:
#                                                    name  \
# 0               A T Still University of Health Sciences
# 1                          Abilene Christian University
# 2                  Abraham Baldwin Agricultural College
# 3                                       Academy College
# 4                  Academy for Five Element Acupuncture
# ...                                                 ...
# 2902  Yo San University of Traditional Chinese Medicine
# 2903                                       York College
# 2904                          York College Pennsylvania
# 2905                        Youngstown State University
# 2906                                 Zion Bible College
#
#                                                 address  \
# 0           800 W Jefferson, Kirksville, Missouri 63501
# 1               1600 Campus Court, Abilene, Texas 79699
# 2            2802 Moore Hwy, Tifton, Georgia 31793-2601
# 3     1101 E. 78th Street, Suite 100, Minneapolis, M...
# 4            305 SE 2nd Ave, Gainesville, Florida 32601
# ...                                                 ...
# 2902  13315 W. Washington Boulevard, Los Angeles, Ca...
# 2903           1125 E 8th St, York, Nebraska 68467-2699
# 2904     Country Club Rd, York, Pennsylvania 17403-3651
# 2905  One University Plaza, Youngstown, Ohio 44555-0001
# 2906  320 South Main Street, Haverhill, Massachusett...
#
#                      Website  \
# 0               WWW.ATSU.EDU
# 1                www.acu.edu
# 2               www.abac.edu
# 3     www.academycollege.edu
# 4      www.acupuncturist.edu
# ...                      ...
# 2902           www.yosan.edu
# 2903           www.york.edu/
# 2904             www.ycp.edu
# 2905             www.ysu.edu
# 2906             www.zbc.edu
#
#                                                    Type     Size  public?  \
# 0                        4-year, Private not-for-profit   3480.0  Private
# 1                        4-year, Private not-for-profit   4669.0  Private
# 2                 4-year, primarily associate's, Public   3600.0   Public
# 3     4-year, primarily associate's, Private for-profit    165.0  Private
# 4                        4-year, Private not-for-profit     51.0  Private
# ...                                                 ...      ...      ...
# 2902                     4-year, Private not-for-profit    139.0  Private
# 2903                     4-year, Private not-for-profit    396.0  Private
# 2904                     4-year, Private not-for-profit   5627.0  Private
# 2905                                     4-year, Public  13704.0   Public
# 2906                     4-year, Private not-for-profit    247.0  Private
#
#               fp_nfp  primarily_associate
# 0     not-for-profit                    0
# 1     not-for-profit                    0
# 2     not-for-profit                    1
# 3         for-profit                    1
# 4     not-for-profit                    0
# ...              ...                  ...
# 2902  not-for-profit                    0
# 2903  not-for-profit                    0
# 2904  not-for-profit                    0
# 2905  not-for-profit                    0
# 2906  not-for-profit                    0
#
# [2907 rows x 8 columns]

# %%
df.fp_nfp.unique()
# df.Type.nunique()
# Out:
# array(['for-profit', 'not-for-profit'], dtype=object)

# %%
df.Type.head()

# %%
Types=df['Type']
Types1=Types.str.split(',', expand=True)

# %%
Types1.head()
# Out:
#         0                        1                    2
# 0  4-year   Private not-for-profit                 None
# 1  4-year   Private not-for-profit                 None
# 2  4-year    primarily associate's               Public
# 3  4-year    primarily associate's   Private for-profit
# 4  4-year   Private not-for-profit                 None

# %%
Types1[1].value_counts()
# Out:
#  Private not-for-profit    1579
#  Public                     618
#  primarily associate's      426
#  Private for-profit         284
# Name: 1, dtype: int64

# %%
# Out:
# ['he, is, a  ,   good b,oy']
